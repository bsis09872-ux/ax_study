# %%
x=5000
x
# Out:
# 5000

# %%
id(x)
# Out:
# 1792953150704

# %%
y = x
y
# Out:
# 5000

# %%
id(y)
# Out:
# 1792953150704

# %%
x=500

# %%
id(x)
# Out:
# 1792953149168

# %%
x=600

# %%
id(x)
# Out:
# 1792953147312

# %%
a = 10
id(a)
# Out:
# 140732311475400

# %%
a = 20
id(a)
# Out:
# 140732487112200

# %%
number_of_students = 100

# %%
type(number_of_students)
# Out:
# int

# %%
pi = 3.14
type(pi)
# Out:
# float

# %%
result = True

# %%
type(result)
# Out:
# bool

# %%
pi = "원주율"

# %%
type(pi)
# Out:
# str
