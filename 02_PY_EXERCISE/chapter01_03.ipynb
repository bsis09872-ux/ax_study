# %% [markdown]
# # VS Code와 주피터 노트북 커널 연결

# %%
print("Hello World!")
# Out:
# Running cells with 'cpython-3.13.14-windows-x86_64-none (3.13.14) (Python 3.13.14)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/bsis0/AppData/Roaming/uv/python/cpython-3.13.14-windows-x86_64-none/python.exe -m pip install ipykernel -U --force-reinstall'
