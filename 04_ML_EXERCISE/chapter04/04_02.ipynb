# %% [markdown]
# # 4장 2강 순환 신경망 아키텍처 구현

# %%
# 영화 리뷰 데이터의 단어 빈도 분석 및 사전 탐색

# 도구 호출
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# 데이터 로드
df = pd.read_csv("ratings.txt", sep='\t')

# 결측치 전처리
